# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
print(type(tips)) # <class 'pandas.core.frame.DataFrame'>
tips.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot( tips['total_bill'],  bins=20) # bins default 10

# %%
sns.jointplot( x= 'total_bill', y='tip', data=tips)

# %%
sns.pairplot(tips) # hue 구분자역할 데이터 추가

# %%
sns.pairplot(tips, hue= 'sex') # hue 구분자역할 데이터 추가

# %%
sns.barplot(x='sex', y='total_bill',data=tips)

# %%
#  groupby 데이터 개수
# sns.countplot(x='sex', data=tips)
sns.countplot(x='day', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
# 상관
tc = tips.corr()
sns.heatmap(tc, annot=True)

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
fp = flights.pivot_table(index='month', columns='year', values='passengers')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp)
# plt.figure(figsize=(12,6))
# sns.heatmap(fp, annot=True)

# %%
sns.clustermap(fp)

# %%
sns.lmplot(x='total_bill', y='tip',data=tips, hue='sex', markers=['o','v']) # LMPLOT # i아님
