# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from IPython.display import HTML, display # jupyter 사진넣기

import matplotlib as mpl               # 한글깨짐
import matplotlib.font_manager as fm   # 한글깨짐
import matplotlib.font_manager         # 한글깨짐

# %%
names = ['기준년도', '가입자일련번호', '성별코드', '연령대코드(5세단위)', '시도코드', '신장(5Cm단위)',
       '체중(5Kg단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
       '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
       '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
       '음주여부', '구강검진수검여부', '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상', '치석',
       '데이터공개일자']
df = pd.read_csv('./data/NHIS_total.csv', names=names)
df=df.drop(0)
print(df.head(5))
df.info()
# Out:
#    기준년도 가입자일련번호 성별코드 연령대코드(5세단위) 시도코드 신장(5Cm단위) 체중(5Kg단위) 허리둘레 시력(좌) 시력(우)  \
# 1  2009  279847    2          14   41       135        35   79   9.9   0.1
# 2  2009   46535    2           1   26       145        40   62     1     1
# 3  2009  180895    2           1   11       145        40   58     1   1.2
# 4  2009   19658    2           1   11       145        40   67   1.2   1.2
# 5  2009   18537    2           1   41       145        40   67   0.3   0.3
#
#      ...    감마지티피 흡연상태 음주여부 구강검진수검여부 치아우식증유무 결손치유무 치아마모증유무 제3대구치(사랑니)이상   치석  \
# 1    ...       13    1    0        0     NaN   NaN     NaN          NaN  NaN
# 2    ...       11    1    0        0     NaN   NaN     NaN          NaN  NaN
# 3    ...        7    1    0        1       1     0       0            0    0
# 4    ...       12    1    0        1       1     0       0            0    0
# 5    ...        7    1    1        1     NaN     0       0            0    0
#
#     데이터공개일자
# 1  20151220
# 2  20151220
# 3  20151220
# 4  20151220
# 5  20151220
#
# [5 rows x 34 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17000000 entries, 1 to 17000000
# Data columns (total 34 columns):
# 기준년도            object
# 가입자일련번호         object
# 성별코드            object
# 연령대코드(5세단위)     object
# 시도코드            object
# 신장(5Cm단위)       object
# 체중(5Kg단위)       object
# 허리둘레            object
# 시력(좌)           object
# 시력(우)           object
# 청력(좌)           object
# 청력(우)           object
# 수축기혈압           object
# 이완기혈압           object
# 식전혈당(공복혈당)      object
# 총콜레스테롤          object
# 트리글리세라이드        object
# HDL콜레스테롤        object
# LDL콜레스테롤        object
# 혈색소             object
# 요단백             object
# 혈청크레아티닌         object
# (혈청지오티)AST      object
# (혈청지오티)ALT      object
# 감마지티피           object
# 흡연상태            object
# 음주여부            object
# 구강검진수검여부        object
# 치아우식증유무         object
# 결손치유무           object
# 치아마모증유무         object
# 제3대구치(사랑니)이상    object
# 치석              object
# 데이터공개일자         object
# dtypes: object(34)
# memory usage: 4.4+ GB

# %% [markdown]
# ### 데이터타입 변경필요(범주형 int32, 수치형 float64)

# %%
# category_features = ['기준년도', '성별코드', '연령대코드(5세단위)', '시도코드', '청력(좌)','청력(우)', '요단백', 
#                      '흡연상태', '음주여부', '구강검진수검여부']
# for feature in category_features:
#     df[feature] = pd.to_numeric(df[feature])

# %%
#### for문 리눅스 서버 memory error 개별로 처리

# %%
feature = '기준년도'
df[feature] = pd.to_numeric(df[feature])

# %%
feature = '성별코드'
df[feature] = pd.to_numeric(df[feature])

# %%
feature = '연령대코드(5세단위)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature = '시도코드'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '청력(좌)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '청력(우)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '요단백'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '흡연상태'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '음주여부'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '구강검진수검여부'
df[feature] = pd.to_numeric(df[feature])

# %%
# numberic_features = ['신장(5Cm단위)', '체중(5Kg단위)', '허리둘레','시력(좌)', '시력(우)', 
#                      '수축기혈압', '이완기혈압', '식전혈당(공복혈당)','총콜레스테롤', 
#                      '트리글리세라이드', 'HDL콜레스테롤','LDL콜레스테롤', '혈색소', '혈청크레아티닌',
#                        '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피']
# for feature in numberic_features:
#     df[feature] = pd.to_numeric(df[feature])
# # df.info()

# %%
feature =  '신장(5Cm단위)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '체중(5Kg단위)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '허리둘레'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '시력(좌)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '시력(우)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '수축기혈압'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '이완기혈압'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '식전혈당(공복혈당)'
df[feature] = pd.to_numeric(df[feature])

# %%
feature = '총콜레스테롤' 
df[feature] = pd.to_numeric(df[feature])

# %%
feature = '트리글리세라이드'
df[feature] = pd.to_numeric(df[feature])

# %%
feature = 'HDL콜레스테롤'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  'LDL콜레스테롤'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '혈색소'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '혈청크레아티닌'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =   '(혈청지오티)AST'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =   '(혈청지오티)ALT'
df[feature] = pd.to_numeric(df[feature])

# %%
feature =  '감마지티피'
df[feature] = pd.to_numeric(df[feature])

# %% [markdown]
# ### target feature  static

# %%
df['target'] = df['식전혈당(공복혈당)'].map(lambda x:  1 if x >= 126 else 0)

tmp_lst=df['target'].value_counts().values
print(f'정상(2002 ~ 2018, 1700만 데이터, target < 126 ) {np.round((tmp_lst[0]/tmp_lst.sum())*100, 2)}%')
print(f'당뇨(2002 ~ 2018, 1700만 데이터, target >= 126 ) {np.round((tmp_lst[1]/tmp_lst.sum())*100, 2)}%')
# Out:
# 정상(2002 ~ 2018, 1700만 데이터, target < 126 ) 60.89%
# 당뇨(2002 ~ 2018, 1700만 데이터, target >= 126 ) 39.11%

# %% [markdown]
# #### plot

# %%
df_year = df.groupby(['기준년도','target'])['target'].count()
df_year = df_year.reset_index(name="target_count")
df_year = df_year.set_index('기준년도')

# %%
# linux 
font_dirs = ['/home/sch/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)
font_list = fm.createFontList(font_files)
fm.fontManager.ttflist.extend(font_list)
[f.name for f in matplotlib.font_manager.fontManager.ttflist if 'Nanum' in f.name][:3]
# Out:
# ['NanumMyeongjo Eco', 'NanumMyeongjo', 'NanumGothicCoding']

# %%
# temp_dict={'target_count': (10000,1000000)}
def Plot(df):
    plt.figure(figsize=(12,12))
#     fig, ax =plt.figure(figsize=(8,4))
    sns.set(font_scale=1.0)

#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf

       # 한글깨짐 리눅스
    mpl.rcParams['font.family'] = 'NanumGothic'
    mpl.rc('axes', unicode_minus=False)
    ax = sns.barplot(x=df_year.index, y=df_year['target_count'], data=df, hue='target')
#         start, end = tup
#         ax.set_ylim(start, end)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right') 
    plt.title(f'2002 ~ 2018 당뇨 (0 : 공복혈당 126mg/mL미만, 1 : 공복혈당 126mg/mL이상) ')
    plt.savefig(f"./img/visual/2002_2018_diabete_static.png",dpi=200, bbox_inches='tight')
    plt.show()
#     plt.close()
Plot(df_year)

# %% [markdown]
# #### 식전혈당(공복혈당)feature 입력된 내용이 2002 ~ 2007까지는 대부분 126ml 이상으로 target으로 활용할 수 없어 삭제해야 함

# %% [markdown]
# ### 2002 ~ 2007 remove (diabete data not stable)

# %%
df=df[ df['기준년도']  != 2002  ]

# %%
df=df[ df['기준년도']  != 2003  ]

# %%
df=df[ df['기준년도']  != 2004  ]

# %%
df=df[ df['기준년도']  != 2005  ]

# %%
df=df[ df['기준년도']  != 2006  ]

# %%
df=df[ df['기준년도']  != 2007  ]

# %% [markdown]
# #### diabete static

# %%
tmp_lst=df['target'].value_counts().values
print(f'정상(2008 ~ 2018, 1700만 데이터, target < 126 ) {np.round((tmp_lst[0]/tmp_lst.sum())*100, 2)}%')
print(f'당뇨(2008 ~ 2018, 1700만 데이터, target >= 126 ) {np.round((tmp_lst[1]/tmp_lst.sum())*100, 2)}%')
# Out:
# 정상(2008 ~ 2018, 1700만 데이터, target < 126 ) 93.27%
# 당뇨(2008 ~ 2018, 1700만 데이터, target >= 126 ) 6.73%

# %% [markdown]
# ## null, zero 0 value count (by year)

# %%
df.isnull().sum()
# Out:
# 기준년도                  0
# 가입자일련번호               0
# 성별코드                  0
# 연령대코드(5세단위)           0
# 시도코드                  0
# 신장(5Cm단위)           897
# 체중(5Kg단위)           897
# 허리둘레                873
# 시력(좌)              1927
# 시력(우)              1999
# 청력(좌)              1842
# 청력(우)              1850
# 수축기혈압              5837
# 이완기혈압              5837
# 식전혈당(공복혈당)         6005
# 총콜레스테롤           667330
# 트리글리세라이드         667341
# HDL콜레스테롤         670928
# LDL콜레스테롤         723244
# 혈색소                6024
# 요단백               49198
# 혈청크레아티닌           87224
# (혈청지오티)AST        84119
# (혈청지오티)ALT         5991
# 감마지티피            636251
# 흡연상태             655665
# 음주여부            2019159
# 구강검진수검여부         948475
# 치아우식증유무         8746468
# 결손치유무           7345833
# 치아마모증유무         7109677
# 제3대구치(사랑니)이상    9338068
# 치석              7907413
# 데이터공개일자         3000000
# target                0
# dtype: int64

# %% [markdown]
# ### Plot null static by year

# %%
df_null = df.groupby('기준년도').apply(lambda x: x.isnull().sum())
def Plot(df):
    for column in df.columns:
        plt.figure(figsize=(12,12))
    #     fig, ax =plt.figure(figsize=(8,4))
        sns.set(font_scale=1.0)
        
#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf

           # 한글깨짐 리눅스
        mpl.rcParams['font.family'] = 'NanumGothic'
        mpl.rc('axes', unicode_minus=False)
        ax = sns.barplot(x=df.index, y=column, data=df)

#         ax.set_ylim(500, 50000)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right') 
        plt.title(f'결측치 null값 합계 {column} 2002 ~ 2018')
        plt.savefig(f"./img/visualNull/2002_2018_null_{column}_count.png",dpi=200, bbox_inches='tight')
        plt.show()
    #     plt.close()
Plot(df_null)

# %% [markdown]
# #### 결측치(null)
# * 결측치 800만 ~ 1300만 feature '치아우식증유무', '결손치유무', '치아마모증유무', '제3대구치(사랑니)이상', '치석'feature
#    ==> 데이터 결측이 너무 많아 데이터로 가치가 없어 feature 삭제
# * 2018년 100만건중 '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤' 항목은 66만건이 null값
#   ===> 최근년도 데이터라서 모델용으로 사용(2018년도는 100만건중 33만건만 모델용으로 사용하게 됨)
#   ===> 공단문의결과 '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤' 4개항목이 2018년도부터 4년주기로 변경됨
# * 2008년 자료에서는 감마지피티 feature가 100만건중 66만건이 결측치
# * 음주여부 총 200만건중 결측치 136만 : 2016년에만 100만건, 2018년도 36만건, 2008년 66만건, 2009년에도 있고
#   - 2016년에만 100만건으로 전체가 null처리되어 있어, 공단문의결과 공단측담당자"입력값이 없다.엔지니어와 상의하여 연락주겠다"
#   ===> 음주여부 null filter
# * '데이터공개일자' 목적과 관계없어 feature 삭제
# * 여타 feature 결측치는 양이 897 ~ 50000사이로 fiter 처리
#     - ['신장(5Cm단위)', '체중(5Kg단위)', '허리둘레',
#        '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)',
#        '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤', '혈색소', '요단백', '혈청크레아티닌',
#        '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '구강검진수검여부']

# %% [markdown]
# ### 결측치(null) 처리

# %% [markdown]
# #### 7 feature drop (34feature -> 27feature)
# * '가입자일련번호','결손치유무', '치아우식증유무', '치아마모증유무', '제3대구치(사랑니)이상','치석','데이터공개일자' drop

# %%
df.drop(['가입자일련번호','결손치유무', '치아우식증유무', '치아마모증유무', '제3대구치(사랑니)이상','치석','데이터공개일자'], axis=1, inplace=True)

# %% [markdown]
#  #### filter
#  ['신장(5Cm단위)', '체중(5Kg단위)', '허리둘레','시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압',
#  '식전혈당(공복혈당)','총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤', '혈색소', '요단백', '혈청크레아티닌',
#  '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피','음주여부', '흡연상태', '구강검진수검여부']

# %%
df=df[df['신장(5Cm단위)'].notnull()]

# %%
df=df[df['체중(5Kg단위)'].notnull()]

# %%
df=df[df['허리둘레'].notnull()]

# %%
df=df[df['시력(좌)'].notnull()]

# %%
df=df[df['시력(우)'].notnull()]

# %%
df=df[df['청력(좌)'].notnull()]

# %%
df=df[df['청력(우)'].notnull()]

# %%
df=df[df['수축기혈압'].notnull()]

# %%
df=df[df['이완기혈압'].notnull()]

# %%
df=df[df['식전혈당(공복혈당)'].notnull()]

# %%
df=df[df['총콜레스테롤'].notnull()]

# %%
df=df[df['트리글리세라이드'].notnull()]

# %%
df=df[df['HDL콜레스테롤'].notnull()]

# %%
df=df[df['LDL콜레스테롤'].notnull()]

# %%
df=df[df['혈색소'].notnull()]

# %%
df=df[df['요단백'].notnull()]

# %%
df=df[df['혈청크레아티닌'].notnull()]

# %%
df=df[df['(혈청지오티)AST'].notnull()]

# %%
df=df[df['(혈청지오티)ALT'].notnull()]

# %%
df=df[df['감마지티피'].notnull()]

# %%
df=df[df['흡연상태'].notnull()]

# %%
df=df[df['음주여부'].notnull()]

# %%
df=df[df['구강검진수검여부'].notnull()]

# %% [markdown]
# ### zero 0 value ('음주여부', '구강검진수검여부'만 0값이 존재할 수 있음 )

# %%
(df == 0).sum()
# Out:
# 기준년도                 0
# 성별코드                 0
# 연령대코드(5세단위)          0
# 시도코드                 0
# 신장(5Cm단위)            0
# 체중(5Kg단위)            0
# 허리둘레                 0
# 시력(좌)                0
# 시력(우)                0
# 청력(좌)                0
# 청력(우)                0
# 수축기혈압                0
# 이완기혈압                0
# 식전혈당(공복혈당)           0
# 총콜레스테롤               0
# 트리글리세라이드             0
# HDL콜레스테롤             0
# LDL콜레스테롤          1747
# 혈색소                  0
# 요단백                  0
# 혈청크레아티닌              0
# (혈청지오티)AST       18768
# (혈청지오티)ALT           0
# 감마지티피            33633
# 흡연상태             42584
# 음주여부           4065424
# 구강검진수검여부       4973186
# target         7609672
# dtype: int64

# %%
(df == np.nan).sum()
# Out:
# 기준년도           0
# 성별코드           0
# 연령대코드(5세단위)    0
# 시도코드           0
# 신장(5Cm단위)      0
# 체중(5Kg단위)      0
# 허리둘레           0
# 시력(좌)          0
# 시력(우)          0
# 청력(좌)          0
# 청력(우)          0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# 구강검진수검여부       0
# target         0
# dtype: int64

# %%
df_0 = df.groupby('기준년도').apply(lambda x: (x ==0).sum())
def Plot(df):
    for column in df.columns:
        plt.figure(figsize=(12,4))
    #     fig, ax =plt.figure(figsize=(8,4))
        sns.set(font_scale=1.0)
        
#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf

           # 한글깨짐 리눅스
        mpl.rcParams['font.family'] = 'NanumGothic'
        mpl.rc('axes', unicode_minus=False)
        ax = sns.barplot(x=df.index, y=column, data=df)

#         ax.set_ylim(500, 50000)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right') 
        plt.title(f'zero 0 값 합계 {column} 2008 ~ 2018')
        plt.savefig(f"./img/visualNull/2008_2018_null_{column}_count.png",dpi=200, bbox_inches='tight')
        plt.show()
    #     plt.close()
Plot(df_0)

# %%
df.columns

# %%
#### zero value는 'LDL콜레스테롤' 1747,  '(혈청지오티)AST' 18768  '감마지티피' 33633, 흡연상태 42584 다른 이슈없음 : filter

# %%
df = df[df['LDL콜레스테롤'] !=0]

# %%
df = df[df['(혈청지오티)AST'] !=0]

# %%
df = df[df['감마지티피'] !=0]

# %%
df = df[df['흡연상태'] !=0]

# %%
df.info()

# %%
tmp_lst=df['target'].value_counts().values
print(f'정상(2008 ~ 2018, 927만 데이터, target < 126 ) {np.round((tmp_lst[0]/tmp_lst.sum())*100, 2)}%')
print(f'당뇨(2008 ~ 2018, 927만 데이터, target >= 126 ) {np.round((tmp_lst[1]/tmp_lst.sum())*100, 2)}%')

# %% [markdown]
# ### 결측값, 0값 확인

# %%
df.isnull().sum()

# %%
(df == 0).sum(axis=0)

# %%
(df == np.nan).sum(axis=0)

# %% [markdown]
# ### diabete static

# %%
tmp_lst=df['target'].value_counts().values
print(f'정상(target) {np.round((tmp_lst[0]/tmp_lst.sum())*100, 2)}%')
print(f'당뇨(target) {np.round((tmp_lst[1]/tmp_lst.sum())*100, 2)}%')

# %% [markdown]
# ## 이상치(oulier) 제거

# %% [markdown]
# #### 1. 범주형 feature 10개 이상치 확인

# %%
# 범주형 feature 10개
category_features = ['기준년도', '성별코드', '연령대코드(5세단위)', '시도코드', '청력(좌)','청력(우)', '요단백', 
                     '흡연상태', '음주여부', '구강검진수검여부']
def Plot(df,category_features ):
    sns.set(font_scale=1.0)
    fig = plt.figure(figsize=(12,12))

    for i, feature in enumerate(category_features):

        # 한글깨짐 윈도우(window)
#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf
            # 한글깨짐 리눅스
        mpl.rcParams['font.family'] = 'NanumGothic'
        mpl.rc('axes', unicode_minus=False)

        ax = fig.add_subplot(6,3,i+1)
        ax = sns.boxplot(x=df[feature], orient = "v", data = df, palette="Blues")    
        ax.set_title(f'이상치 제거 전 {feature} ')
        
    plt.savefig(f"./img/visual/1700_outlier_catogory_before.png", dpi=100, bbox_inches='tight')
#     plt.tight_layout()
#     plt.colse()
#     plt.show()
    
Plot(df,category_features )

# %% [markdown]
# ####  범주형feature중 요단백 수치만 이상치 발견됨 요단백 수치만 이상치 발견됨

# %%
df['요단백'].value_counts()

# %% [markdown]
# ### 요단백 filter

# %%
df = df[df['요단백'].apply(lambda x: x in [1, 2, 3, 4, 5, 6 ])]
df['요단백'].value_counts()

# %% [markdown]
# #### 2. 수치형 features 이상치 제거전 boxplot 이상치 확인

# %%
numberic_features = ['신장(5Cm단위)', '체중(5Kg단위)', '허리둘레','시력(좌)', '시력(우)', 
                     '수축기혈압', '이완기혈압', '식전혈당(공복혈당)','총콜레스테롤', 
                     '트리글리세라이드', 'HDL콜레스테롤','LDL콜레스테롤', '혈색소', '혈청크레아티닌',
                       '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피']

def Plot(df,numberic_features ):
    sns.set(font_scale=1.0)
    fig = plt.figure(figsize=(12,24))

    for i, feature in enumerate(numberic_features):

        # 한글깨짐 윈도우(window)
#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf
            # 한글깨짐 리눅스
        mpl.rcParams['font.family'] = 'NanumGothic'
        mpl.rc('axes', unicode_minus=False)

        ax = fig.add_subplot(6,3,i+1)
        ax = sns.boxplot(x=df[feature], orient = "v", data = df, palette="Blues")    
        ax.set_title(f'이상치 제거 전 {feature} ')
        
    plt.savefig(f"./img/visual/1700_outlier_numberic_before.png", dpi=100, bbox_inches='tight')
#     plt.tight_layout()
#     plt.colse()
#     plt.show()
    
Plot(df,numberic_features )

# %%
# 개별 boxplot 처리
# for feature in numberic_features:
#     sns.set(font_scale=1.0)
#     plt.figure(figsize=(6,4))
#     # 윈도우(window) 한글처리
#     font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#     mpl.rc('font', family=font_name) # ahronbd.ttf
#     sns.boxplot(x=df[feature], orient = "v", data = df)    
#     plt.title(f'이상치 제거 전 {feature} BOXPlot_1700 ')
#     plt.savefig(f"./img/visual/1700_{feature}_outlier_before.png")
#     plt.show()

#아웃라이어 전체 박스플롯(잘림 있음)
# def outlier_plot(df=None):
#     plt.style.use('ggplot') # Using ggplot2 style visuals 
#     f, ax = plt.subplots(figsize=(15, 15))
#     ax.set_facecolor('#fafafa')
#     ax.set(xlim=(-.05, 200))
#     ax = sns.boxplot(data = df, orient = 'h', palette = 'Set2')
#     plt.savefig('./img/outlier.png')
#     plt.tight_layout()
# #         plt.close(f)
# outlier_plot(old_df)    
# outlier_plot(df)

# %% [markdown]
# ### 3. 이상치 제거

# %% [markdown]
# #### oulier throshold

# %%
# 최대, 최소 범위의 weight 조정
features_dict = {'신장(5Cm단위)' : (5, -60) ,   # 25 ~ 245
                           '체중(5Kg단위)' :(10, 115),   # 20 ~ 220
                           '허리둘레' : (11, 79),        # 10 ~ 230
                           '시력(좌)' : (4, 1.4),        # 0.01 ~ 3.2 # 0.1이하
                           '시력(우)' : (4, 1.4),        # 0.01 ~ 3.2 # 0.1이하
                           '수축기혈압' : (20, 300),     # 10 ~ 530
                           '이완기혈압' : (20, 140),     # 10 ~ 280
                           '식전혈당(공복혈당)' : (70, 1035),  # 2 ~ 1223 
                           '총콜레스테롤' : (15, 571),       # 5 ~ 953
                           '트리글리세라이드' : (15, 1228),  # 26 ~ 1433
                           'HDL콜레스테롤' : (50, 914),      # 9 ~ 1014
                           'LDL콜레스테롤' : (20, 815),      # 5 ~ 1035
                           '혈색소' : (10, 10.01),           #  0.01 ~ 38.3
                           '혈청크레아티닌' : (20, 5.301),   # 0.01 ~ 7.0 
                           '(혈청지오티)AST' : (100, 881.1), # 0.1 ~ 928
                           '(혈청지오티)ALT' : (70, 965.1), # 0.1 ~ 1079
                           '감마지티피' : (20, 465.1)        # 0.1 ~ 519
                        }

# 이상치 index찾기  # 사기데이터가 true것에 대하여 (매우적다 500/280000)
def get_outlier_index(df = None, series=None, weight_tup=None):
    # fraud에 해당하는 column 데이터만 추출, 1/4 분위와 3/4 분위 지점을 np.percentile로 구함. 
#     fraud = df[df['Class']==1][column] # 사기데이터
    print(f'\nseries.name : {series.name}   weight : {weight_tup}')
    weight, lower_adj=weight_tup
    
    quantile_25 = np.percentile(series.values, 25)
    print(f'quantile_25 : {quantile_25}')
    quantile_75 = np.percentile(series.values, 75)
    print(f'quantile_75 : {quantile_75}')
    # IQR을 구하고, IQR에 weight를 곱하여 최대값과 최소값 지점 구함. 
    iqr = quantile_75 - quantile_25
    print(f'iqr : {iqr}')
    iqr_weight = iqr * weight
    print(f'iqr_weight : {iqr_weight}')
    
    # lower 조정계수 반영
    lowest_val = quantile_25 - iqr_weight + lower_adj
    print(f'lowest_val : {lowest_val}')
    
    highest_val = quantile_75 + iqr_weight
    print(f'highest_val : {highest_val}')
        
    # 최대값 보다 크거나, 최소값 보다 작은 값을 아웃라이어로 설정하고 DataFrame index 반환. 
    outlier_index = df[(series < lowest_val) | (series > highest_val)].index
    print(f'outlier_index length : {len(outlier_index)}\n')
    return outlier_index 

for feature, weight_tup in features_dict.items(): 
    get_outlier_index(df=df, series=df[feature], weight_tup=weight_tup)

# %% [markdown]
# #### outlier remove

# %%
def remove_outlier(df):
    outlier_drop_indexs=[]
    for feature, weight_tup in features_dict.items(): 
        outlier_index = get_outlier_index(df=df, series=df[feature], weight_tup=weight_tup)
        if (outlier_index.values.tolist() != []):
            outlier_drop_indexs.extend(outlier_index.values.tolist())
    print(f'len(outlier_drop_indexs) : {len(outlier_drop_indexs)}\n')
    df.drop(outlier_drop_indexs, axis=0, inplace=True)
    return df

df = remove_outlier(df)
df.info()

# %% [markdown]
# #### 수치형 features 이상치 제거 후 boxplot 이상치 확인

# %%
numberic_features = ['신장(5Cm단위)', '체중(5Kg단위)', '허리둘레','시력(좌)', '시력(우)', 
                     '수축기혈압', '이완기혈압', '식전혈당(공복혈당)','총콜레스테롤', 
                     '트리글리세라이드', 'HDL콜레스테롤','LDL콜레스테롤', '혈색소', '혈청크레아티닌',
                       '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피']

def Plot(df,numberic_features ):
    sns.set(font_scale=1.0)
    fig = plt.figure(figsize=(12,24))

    for i, feature in enumerate(numberic_features):

        # 한글깨짐 윈도우(window)
#         font_name = mpl.font_manager.FontProperties(fname='C:/Windows/Fonts/malgun.ttf').get_name() # 폴더구분자 python / 임
#         mpl.rc('font', family=font_name) # ahronbd.ttf
            # 한글깨짐 리눅스
        mpl.rcParams['font.family'] = 'NanumGothic'
        mpl.rc('axes', unicode_minus=False)

        ax = fig.add_subplot(6,3,i+1)
        ax = sns.boxplot(x=df[feature], orient = "v", data = df, palette="Reds")    
        ax.set_title(f'이상치 제거 후 {feature} ')
        
    plt.savefig(f"./img/visual/1700_outlier_numberic_after.png", dpi=100, bbox_inches='tight')
#     plt.tight_layout()
#     plt.colse()
#     plt.show()
    
Plot(df,numberic_features )

# %% [markdown]
# #### 이상치 제거 전후 BOXPlot 비교

# %%
display(HTML("<table><tr><td><img src='./img/visual/1700_outlier_numberic_before.png'></td><td><img src='./img/visual/1700_outlier_numberic_after.png'></td></tr></table>"))

# %% [markdown]
# ### 이상치 제거 전후 당뇨통계 변동확인 6.75% -> 6.68%

# %%
tmp_lst=df['target'].value_counts().values
print(f'정상(target) {np.round((tmp_lst[0]/tmp_lst.sum())*100, 2)}%')
print(f'당뇨(target) {np.round((tmp_lst[1]/tmp_lst.sum())*100, 2)}%')

# %% [markdown]
# #### duplicate row find remove

# %%
duplicateDFRow = df[df.duplicated()]
duplicateDFRow

# %%
df.drop_duplicates(keep=False,inplace=True) 
duplicateDFRow = df[df.duplicated()]
duplicateDFRow

# %% [markdown]
# ### info 확인

# %%
df.info()

# %% [markdown]
# ### random feature 'target' remove

# %%
df.drop('target', axis=1, inplace=True)

# %% [markdown]
# ### 통계시각용과 모델용으로 분리하여 저장

# %%
df.columns

# %%
# 통계시각용 '음주여부' drop
# 2018년도 33만건 밖에 없어 filter
df_visual = df.drop('음주여부', axis=1).copy()
df_visual = df[df['기준년도'] !=2018]
df_visual.info()

# %%
# 모델용 기준년도 2016, 2018 filter
df_model = df[df['기준년도'].apply(lambda x: x != [2016, 2018])].copy()
df_model.info()

# %%
df_visual.to_csv('./data/NHIS_total_visual.csv', sep=',', encoding='utf-8', index=False)

# %%
df_model.to_csv('./data/NHIS_total_model.csv', sep=',', encoding='utf-8', index=False)
